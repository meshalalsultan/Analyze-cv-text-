# %%
apikey = ''
url = ''

# %%
cv = '''
Profile 
Business-minded data scientist with a demonstrated ability to deliver valuable insights via data analytics and advanced data-driven methods,
With deep understanding of neural networks and the ability to explain technical topics,data, machine learning, and statistics.
Passionate about explaining data science to non-technical business audiences,
I have experience using stats and machine-learning to find useful insights in data.

Professional Experience
Analyzed and Predict Stock Price for next day:
Developed and trained Artificial Recurrent Neural network (RNN) on stock dataframe and tested it with loss matrix and accuracy to predict next day price.

Built Twitter and News Sentiment App: 
Create Algorithm with TensorFlow predict the polarity of textual data or sentiments like Positive, Neural, and negative.

Predict What Products Customers Likely Want
Boosted Machine learning to Predict what products customers likely want and then optimize a targeted campaign using advanced decision optimization in a Jupyter notebook. 

Analyzed Public Twitter Profile: 
Established Deeper personality insight on several dimensions, including traits , values , need and consumer preferences . Enhanced with chart plot.

Technical Skills 
Development Machine Learning: 
Classification, Regression, Clustering, Future Engineering, TensorFlow, Transfer Learning, Restful API, Terminal Bash

Programming Language:
Python (Scikit-Learn, NumPy, Pandas, TensorFlow, Matplotlib, SciPy), SQL, Microsoft, HTML, JavaScript, Dart, Excel, Flutter

Statics Methods:
Time Series, Regression Models, Hypothesis Testing.

Visualization:
Tableau, Oracle DVD.

Development Platform:
Web Browser, IOS & Android Apps .

Tools:
Anaconda, Jupyter Notebook, IDE Editor, Android Studio.

Selected Coursework:
Stochastic Gradient Decent, Liner Algebra, Theory, Probity and Statics, A/B Testing

Education 
•	Studying Master Degree in Data Scientist in University of Colorado Bolder
•	Faculty of Business Studies Accountant Diploma 2001-2004		CERTIFICATION 
	
Tensorflow Certified Developer: Googel.com

IBM Applied AI Specialization :

NLP Natural Language Processing with python :  Udemy
Building Ai Powered Chatbot : IBM
Browser Based Model with TensorFlow: deeplearning.io
Machine Learning with Python: Coursera.
Augmented Data Visualization
 
LANGUAGES
Arabic, English

ADDITIONAL INTEREST
Karate
Swimming
Travel 
'''

# %%
import json
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator(apikey)
tone_analyzer = ToneAnalyzerV3(
    version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url(url)

text = cv

tone_analysis = tone_analyzer.tone(
    {'text': text},
    content_type='application/json'
).get_result()
print(json.dumps(tone_analysis, indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.580037,
#         "tone_id": "joy",
#         "tone_name": "Joy"
#       },
#       {
#         "score": 0.901492,
#         "tone_id": "analytical",
#         "tone_name": "Analytical"
#       }
#     ]
#   },
#   "sentences_tone": [
#     {
#       "sentence_id": 0,
#       "text": "Profile ",
#       "tones": []
#     },
#     {
#       "sentence_id": 1,
#       "text": "Business-minded data scientist with a demonstrated ability to deliver valuable insights via data analytics and advanced data-driven methods,",
#       "tones": [
#         {
#           "score": 0.543287,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         },
#         {
#           "score": 0.901894,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 2,
#       "text": "With deep understanding of neural networks and the ability to explain technical topics,data, machine learning, and statistics.",
#       "tones": [
#         {
#           "score": 0.8766,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 3,
#       "text": "Passionate about explaining data science to non-technical business audiences,",
#       "tones": [
#         {
#           "score": 0.501597,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         },
#         {
#           "score": 0.724236,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         },
#         {
#           "score": 0.5538,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 4,
#       "text": "I have experience using stats and machine-learning to find useful insights in data.",
#       "tones": [
#         {
#           "score": 0.947344,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 5,
#       "text": "Professional Experience",
#       "tones": []
#     },
#     {
#       "sentence_id": 6,
#       "text": "Analyzed and Predict Stock Price for next day:",
#       "tones": [
#         {
#           "score": 0.948998,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 7,
#       "text": "Developed and trained Artificial Recurrent Neural network (RNN) on stock dataframe and tested it with loss matrix and accuracy to predict next day price.",
#       "tones": [
#         {
#           "score": 0.518478,
#           "tone_id": "sadness",
#           "tone_name": "Sadness"
#         }
#       ]
#     },
#     {
#       "sentence_id": 8,
#       "text": "Built Twitter and News Sentiment App: ",
#       "tones": [
#         {
#           "score": 0.842108,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 9,
#       "text": "Create Algorithm with TensorFlow predict the polarity of textual data or sentiments like Positive, Neural, and negative.",
#       "tones": [
#         {
#           "score": 0.753704,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         }
#       ]
#     },
#     {
#       "sentence_id": 10,
#       "text": "Predict What Products Customers Likely Want",
#       "tones": [
#         {
#           "score": 0.920855,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         },
#         {
#           "score": 0.946222,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 11,
#       "text": "Boosted Machine learning to Predict what products customers likely want and then optimize a targeted campaign using advanced decision optimization in a Jupyter notebook.",
#       "tones": [
#         {
#           "score": 0.926977,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 12,
#       "text": "Analyzed Public Twitter Profile: ",
#       "tones": [
#         {
#           "score": 0.982476,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 13,
#       "text": "Established Deeper personality insight on several dimensions, including traits , values , need and consumer preferences .",
#       "tones": [
#         {
#           "score": 0.961593,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 14,
#       "text": "Enhanced with chart plot.",
#       "tones": []
#     },
#     {
#       "sentence_id": 15,
#       "text": "Technical Skills ",
#       "tones": []
#     },
#     {
#       "sentence_id": 16,
#       "text": "Development Machine Learning: ",
#       "tones": [
#         {
#           "score": 0.967163,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 17,
#       "text": "Classification, Regression, Clustering, Future Engineering, TensorFlow, Transfer Learning, Restful API, Terminal Bash",
#       "tones": [
#         {
#           "score": 0.672469,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 18,
#       "text": "",
#       "tones": []
#     },
#     {
#       "sentence_id": 19,
#       "text": "Programming Language:",
#       "tones": []
#     },
#     {
#       "sentence_id": 20,
#       "text": "Python (Scikit-Learn, NumPy, Pandas, TensorFlow, Matplotlib, SciPy), SQL, Microsoft, HTML, JavaScript, Dart, Excel, Flutter",
#       "tones": []
#     },
#     {
#       "sentence_id": 21,
#       "text": "",
#       "tones": []
#     },
#     {
#       "sentence_id": 22,
#       "text": "Statics Methods:",
#       "tones": []
#     },
#     {
#       "sentence_id": 23,
#       "text": "Time Series, Regression Models, Hypothesis Testing.",
#       "tones": [
#         {
#           "score": 0.75152,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     },
#     {
#       "sentence_id": 24,
#       "text": "Visualization:",
#       "tones": []
#     },
#     {
#       "sentence_id": 25,
#       "text": "Tableau, Oracle DVD.",
#       "tones": [
#         {
#           "score": 0.541974,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         }
#       ]
#     },
#     {
#       "sentence_id": 26,
#       "text": "Development Platform:",
#       "tones": [
#         {
#           "score": 0.579367,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 27,
#       "text": "Web Browser, IOS & Android Apps .",
#       "tones": []
#     },
#     {
#       "sentence_id": 28,
#       "text": "Tools:",
#       "tones": []
#     },
#     {
#       "sentence_id": 29,
#       "text": "Anaconda, Jupyter Notebook, IDE Editor, Android Studio.",
#       "tones": []
#     },
#     {
#       "sentence_id": 30,
#       "text": "Selected Coursework:",
#       "tones": []
#     },
#     {
#       "sentence_id": 31,
#       "text": "Stochastic Gradient Decent, Liner Algebra, Theory, Probity and Statics, A/B Testing",
#       "tones": []
#     },
#     {
#       "sentence_id": 32,
#       "text": "",
#       "tones": []
#     },
#     {
#       "sentence_id": 33,
#       "text": "Education ",
#       "tones": []
#     },
#     {
#       "sentence_id": 34,
#       "text": "\u2022\tStudying Master Degree in Data Scientist in University of Colorado Bolder",
#       "tones": [
#         {
#           "score": 0.739199,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         }
#       ]
#     },
#     {
#       "sentence_id": 35,
#       "text": "\u2022\tFaculty of Business Studies Accountant Diploma 2001-2004\t\tCERTIFICATION ",
#       "tones": [
#         {
#           "score": 0.523738,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         }
#       ]
#     },
#     {
#       "sentence_id": 36,
#       "text": "\t",
#       "tones": []
#     },
#     {
#       "sentence_id": 37,
#       "text": "Tensorflow Certified Developer: Googel.com",
#       "tones": []
#     },
#     {
#       "sentence_id": 38,
#       "text": "IBM Applied AI Specialization :",
#       "tones": []
#     },
#     {
#       "sentence_id": 39,
#       "text": "",
#       "tones": []
#     },
#     {
#       "sentence_id": 40,
#       "text": "NLP Natural Language Processing with python :  Udemy",
#       "tones": []
#     },
#     {
#       "sentence_id": 41,
#       "text": "Building Ai Powered Chatbot : IBM",
#       "tones": []
#     },
#     {
#       "sentence_id": 42,
#       "text": "Browser Based Model with TensorFlow: deeplearning.io",
#       "tones": [
#         {
#           "score": 0.838593,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 43,
#       "text": "Machine Learning with Python: Coursera.",
#       "tones": [
#         {
#           "score": 0.882284,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     },
#     {
#       "sentence_id": 44,
#       "text": "Augmented Data Visualization",
#       "tones": []
#     },
#     {
#       "sentence_id": 45,
#       "text": " ",
#       "tones": []
#     },
#     {
#       "sentence_id": 46,
#       "text": "LANGUAGES",
#       "tones": []
#     },
#     {
#       "sentence_id": 47,
#       "text": "Arabic, English",
#       "tones": []
#     },
#     {
#       "sentence_id": 48,
#       "text": "",
#       "tones": []
#     },
#     {
#       "sentence_id": 49,
#       "text": "ADDITIONAL INTEREST",
#       "tones": []
#     },
#     {
#       "sentence_id": 50,
#       "text": "Karate",
#       "tones": []
#     },
#     {
#       "sentence_id": 51,
#       "text": "Swimming",
#       "tones": []
#     },
#     {
#       "sentence_id": 52,
#       "text": "Travel",
#       "tones": []
#     }
#   ]
# }

# %% [markdown]
# <span>
# <h1> For The Natural Language Understanding </h1>
# </span>

# %%
napikey = ''
nurl = ''

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions,ConceptsOptions

authenticator = IAMAuthenticator(napikey)
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2021-03-25',
    authenticator=authenticator)

natural_language_understanding.set_service_url(nurl)

response = natural_language_understanding.analyze(
    text=cv,
    features=Features(
        entities=EntitiesOptions(emotion=True, sentiment=True, limit=2),
        keywords=KeywordsOptions(emotion=True, sentiment=True,limit=2),
        concepts=ConceptsOptions(limit=3)),
    ).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 2399,
#     "features": 3
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "data analytics",
#       "sentiment": {
#         "score": 0.905135,
#         "label": "positive"
#       },
#       "relevance": 0.656751,
#       "emotion": {
#         "sadness": 0.035258,
#         "joy": 0.543287,
#         "fear": 0.066289,
#         "disgust": 0.018939,
#         "anger": 0.03522
#       },
#       "count": 1
#     },
#     {
#       "text": "deep understanding of neural networks",
#       "sentiment": {
#         "score": 0.785362,
#         "label": "positive"
#       },
#       "relevance": 0.654558,
#       "emotion": {
#         "sadness": 0.11001,
#         "joy": 0.152386,
#         "fear": 0.060797,
#         "disgust": 0.067326,
#         "anger": 0.056237
#       },
#       "count": 1
#     }
#   ],
#   "entities": [
#     {
#       "type": "JobTitle",
#       "text": "data scientist",
#       "sentiment": {
#         "score": 0.905135,
#         "label": "positive"
#       },
#       "relevance": 0.949449,
#       "emotion": {
#         "sadness": 0.035258,
#         "joy": 0.543287,
#         "fear": 0.066289,
#         "disgust": 0.018939,
#         "anger": 0.03522
#       },
#       "count": 1,
#       "confidence": 0.637613
#     },
#     {
#       "type": "Organization",
#       "text": "Artificial Recurrent Neural network",
#       "sentiment": {
#         "score": -0.705422,
#         "label": "negative"
#       },
#       "relevance": 0.790411,
#       "emotion": {
#         "sadness": 0.518478,
#         "joy": 0.105198,
#         "fear": 0.094219,
#         "disgust": 0.032929,
#         "anger": 0.033742
#       },
#       "count": 1,
#       "confidence": 0.406564
#     }
#   ],
#   "concepts": [
#     {
#       "text": "Artificial intelligence",
#       "relevance": 0.983217,
#       "dbpedia_resource": "http://dbpedia.org/resource/Artificial_intelligence"
#     },
#     {
#       "text": "Machine learning",
#       "relevance": 0.767953,
#       "dbpedia_resource": "http://dbpedia.org/resource/Machine_learning"
#     },
#     {
#       "text": "Scientific method",
#       "relevance": 0.738272,
#       "dbpedia_resource": "http://dbpedia.org/resource/Scientific_method"
#     }
#   ]
# }

# %%
response['keywords'][0]#['text']
# Out:
# {'text': 'data analytics',
#  'sentiment': {'score': 0.905135, 'label': 'positive'},
#  'relevance': 0.656751,
#  'emotion': {'sadness': 0.035258,
#   'joy': 0.543287,
#   'fear': 0.066289,
#   'disgust': 0.018939,
#   'anger': 0.03522},
#  'count': 1}

# %%
len(response['keywords'])
# Out:
# 2

# %%
response['keywords'][0]['sentiment'].keys()#['score']
# Out:
# dict_keys(['score', 'label'])

# %%
response['keywords'][0]['sentiment'].values()
# Out:
# dict_values([0.905135, 'positive'])

# %%
response.keys()
# Out:
# dict_keys(['usage', 'language', 'keywords', 'entities', 'concepts'])

# %%
response['entities']
# Out:
# [{'type': 'JobTitle',
#   'text': 'data scientist',
#   'sentiment': {'score': 0.905135, 'label': 'positive'},
#   'relevance': 0.949449,
#   'emotion': {'sadness': 0.035258,
#    'joy': 0.543287,
#    'fear': 0.066289,
#    'disgust': 0.018939,
#    'anger': 0.03522},
#   'count': 1,
#   'confidence': 0.637613},
#  {'type': 'Organization',
#   'text': 'Artificial Recurrent Neural network',
#   'sentiment': {'score': -0.705422, 'label': 'negative'},
#   'relevance': 0.790411,
#   'emotion': {'sadness': 0.518478,
#    'joy': 0.105198,
#    'fear': 0.094219,
#    'disgust': 0.032929,
#    'anger': 0.033742},
#   'count': 1,
#   'confidence': 0.406564}]

# %%
for k in response['entities']:
    print (k.keys())
    print (k.values())
# Out:
# dict_keys(['type', 'text', 'sentiment', 'relevance', 'emotion', 'count', 'confidence'])
# dict_values(['JobTitle', 'data scientist', {'score': 0.905135, 'label': 'positive'}, 0.949449, {'sadness': 0.035258, 'joy': 0.543287, 'fear': 0.066289, 'disgust': 0.018939, 'anger': 0.03522}, 1, 0.637613])
# dict_keys(['type', 'text', 'sentiment', 'relevance', 'emotion', 'count', 'confidence'])
# dict_values(['Organization', 'Artificial Recurrent Neural network', {'score': -0.705422, 'label': 'negative'}, 0.790411, {'sadness': 0.518478, 'joy': 0.105198, 'fear': 0.094219, 'disgust': 0.032929, 'anger': 0.033742}, 1, 0.406564])
